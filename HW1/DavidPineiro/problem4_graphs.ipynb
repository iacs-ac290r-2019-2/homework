# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Problem (a) Specifications
# Problem size N: 100
#
# Initial Conditions: f = 0
#
# Boundary condition: h_bound=1.00, g_bound= 0.00

# %% [markdown]
# Value of matrices
#
# K_diag:
# 100.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000
#
# K_subdiag:
# -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000
#
# RHS vector F:
# 1.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000
#
# Solution u:
# 1.000000 0.990000 0.980000 0.970000 0.960000 0.950000 0.940000 0.930000 0.920000 0.910000 0.900000 0.890000 0.880000 0.870000 0.860000 0.850000 0.840000 0.830000 0.820000 0.810000 0.800000 0.790000 0.780000 0.770000 0.760000 0.750000 0.740000 0.730000 0.720000 0.710000 0.700000 0.690000 0.680000 0.670000 0.660000 0.650000 0.640000 0.630000 0.620000 0.610000 0.600000 0.590000 0.580000 0.570000 0.560000 0.550000 0.540000 0.530000 0.520000 0.510000 0.500000 0.490000 0.480000 0.470000 0.460000 0.450000 0.440000 0.430000 0.420000 0.410000 0.400000 0.390000 0.380000 0.370000 0.360000 0.350000 0.340000 0.330000 0.320000 0.310000 0.300000 0.290000 0.280000 0.270000 0.260000 0.250000 0.240000 0.230000 0.220000 0.210000 0.200000 0.190000 0.180000 0.170000 0.160000 0.150000 0.140000 0.130000 0.120000 0.110000 0.100000 0.090000 0.080000 0.070000 0.060000 0.050000 0.040000 0.030000 0.020000 0.010000 0.000000

# %%
N = 100
sol_u = "1.000000 0.990000 0.980000 0.970000 0.960000 0.950000 0.940000 0.930000 0.920000 0.910000 0.900000 0.890000 0.880000 0.870000 0.860000 0.850000 0.840000 0.830000 0.820000 0.810000 0.800000 0.790000 0.780000 0.770000 0.760000 0.750000 0.740000 0.730000 0.720000 0.710000 0.700000 0.690000 0.680000 0.670000 0.660000 0.650000 0.640000 0.630000 0.620000 0.610000 0.600000 0.590000 0.580000 0.570000 0.560000 0.550000 0.540000 0.530000 0.520000 0.510000 0.500000 0.490000 0.480000 0.470000 0.460000 0.450000 0.440000 0.430000 0.420000 0.410000 0.400000 0.390000 0.380000 0.370000 0.360000 0.350000 0.340000 0.330000 0.320000 0.310000 0.300000 0.290000 0.280000 0.270000 0.260000 0.250000 0.240000 0.230000 0.220000 0.210000 0.200000 0.190000 0.180000 0.170000 0.160000 0.150000 0.140000 0.130000 0.120000 0.110000 0.100000 0.090000 0.080000 0.070000 0.060000 0.050000 0.040000 0.030000 0.020000 0.010000 0.000000"
sol_u = [float(x) for x in sol_u.split(" ")]
xx = np.linspace(0, 1, N)

# %%
def act_u0(x):
    return 1 - x

# %%
plt.figure(figsize=(10, 5))
plt.plot(xx,sol_u[1:], label='finite elem est')
plt.plot(xx, act_u0(xx), label='actual val')
plt.title('f = 0, g = 0.0, h = 1.0')
plt.ylabel('u(x)')
plt.xlabel('x')
plt.legend()
plt.savefig('f0_g0_h1.png')
plt.show()

# %% [markdown]
# ### Problem (b) Specifications
# Problem size N: 100
#
# Initial Conditions: f = 0
#
# Boundary condition: h_bound=1.00, g_bound= 1.00

# %% [markdown]
# Value of matrices
#
# K_diag:
# 100.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000
#
# K_subdiag:
# -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000
#
# RHS vector F:
# 1.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 100.000000
#
# Solution u:
# 2.000000 1.990000 1.980000 1.970000 1.960000 1.950000 1.940000 1.930000 1.920000 1.910000 1.900000 1.890000 1.880000 1.870000 1.860000 1.850000 1.840000 1.830000 1.820000 1.810000 1.800000 1.790000 1.780000 1.770000 1.760000 1.750000 1.740000 1.730000 1.720000 1.710000 1.700000 1.690000 1.680000 1.670000 1.660000 1.650000 1.640000 1.630000 1.620000 1.610000 1.600000 1.590000 1.580000 1.570000 1.560000 1.550000 1.540000 1.530000 1.520000 1.510000 1.500000 1.490000 1.480000 1.470000 1.460000 1.450000 1.440000 1.430000 1.420000 1.410000 1.400000 1.390000 1.380000 1.370000 1.360000 1.350000 1.340000 1.330000 1.320000 1.310000 1.300000 1.290000 1.280000 1.270000 1.260000 1.250000 1.240000 1.230000 1.220000 1.210000 1.200000 1.190000 1.180000 1.170000 1.160000 1.150000 1.140000 1.130000 1.120000 1.110000 1.100000 1.090000 1.080000 1.070000 1.060000 1.050000 1.040000 1.030000 1.020000 1.010000 1.000000

# %%
sol_u2 = "2.000000 1.990000 1.980000 1.970000 1.960000 1.950000 1.940000 1.930000 1.920000 1.910000 1.900000 1.890000 1.880000 1.870000 1.860000 1.850000 1.840000 1.830000 1.820000 1.810000 1.800000 1.790000 1.780000 1.770000 1.760000 1.750000 1.740000 1.730000 1.720000 1.710000 1.700000 1.690000 1.680000 1.670000 1.660000 1.650000 1.640000 1.630000 1.620000 1.610000 1.600000 1.590000 1.580000 1.570000 1.560000 1.550000 1.540000 1.530000 1.520000 1.510000 1.500000 1.490000 1.480000 1.470000 1.460000 1.450000 1.440000 1.430000 1.420000 1.410000 1.400000 1.390000 1.380000 1.370000 1.360000 1.350000 1.340000 1.330000 1.320000 1.310000 1.300000 1.290000 1.280000 1.270000 1.260000 1.250000 1.240000 1.230000 1.220000 1.210000 1.200000 1.190000 1.180000 1.170000 1.160000 1.150000 1.140000 1.130000 1.120000 1.110000 1.100000 1.090000 1.080000 1.070000 1.060000 1.050000 1.040000 1.030000 1.020000 1.010000 1.000000"
sol_u2 = [float(x) for x in sol_u2.split(" ")]

# %%
def act_u2(x):
    return 2 - x

# %%
plt.figure(figsize=(10, 5))
plt.plot(xx,sol_u2[1:], label='finite elem est')
plt.plot(xx, act_u2(xx), label='actual val')
plt.title('f = 0, g = 1.0, h = 1.0')
plt.ylabel('u(x)')
plt.xlabel('x')
plt.legend()
plt.savefig('f0_g1_h1.png')
plt.show()

# %% [markdown]
# ### Problem (c) Specifications
# Problem size N: 100
#
# Initial Conditions: f = 1
#
# Boundary condition: h_bound=1.00, g_bound= 1.00

# %% [markdown]
# Value of matrices
#
# K_diag:
# 100.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000 200.000000
#
# K_subdiag:
# -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000 -100.000000
#
# RHS vector F:
# 1.005000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 0.010000 100.010002
#
# Solution u:
# 2.500000 2.489950 2.479800 2.469550 2.459200 2.448750 2.438200 2.427550 2.416800 2.405950 2.395000 2.383950 2.372800 2.361550 2.350200 2.338750 2.327200 2.315550 2.303800 2.291950 2.280000 2.267950 2.255800 2.243550 2.231200 2.218750 2.206200 2.193550 2.180800 2.167950 2.155000 2.141950 2.128800 2.115550 2.102200 2.088750 2.075200 2.061550 2.047800 2.033950 2.020000 2.005950 1.991800 1.977550 1.963200 1.948750 1.934200 1.919550 1.904800 1.889950 1.875000 1.859950 1.844800 1.829550 1.814200 1.798750 1.783200 1.767550 1.751800 1.735950 1.720000 1.703950 1.687800 1.671550 1.655200 1.638750 1.622200 1.605550 1.588800 1.571950 1.555000 1.537950 1.520800 1.503550 1.486200 1.468750 1.451200 1.433550 1.415800 1.397950 1.380000 1.361950 1.343800 1.325550 1.307200 1.288750 1.270200 1.251550 1.232800 1.213950 1.195000 1.175950 1.156800 1.137550 1.118200 1.098750 1.079200 1.059550 1.039800 1.019950 1.000000

# %%
N = 100
sol_u3 = "2.500000 2.489950 2.479800 2.469550 2.459200 2.448750 2.438200 2.427550 2.416800 2.405950 2.395000 2.383950 2.372800 2.361550 2.350200 2.338750 2.327200 2.315550 2.303800 2.291950 2.280000 2.267950 2.255800 2.243550 2.231200 2.218750 2.206200 2.193550 2.180800 2.167950 2.155000 2.141950 2.128800 2.115550 2.102200 2.088750 2.075200 2.061550 2.047800 2.033950 2.020000 2.005950 1.991800 1.977550 1.963200 1.948750 1.934200 1.919550 1.904800 1.889950 1.875000 1.859950 1.844800 1.829550 1.814200 1.798750 1.783200 1.767550 1.751800 1.735950 1.720000 1.703950 1.687800 1.671550 1.655200 1.638750 1.622200 1.605550 1.588800 1.571950 1.555000 1.537950 1.520800 1.503550 1.486200 1.468750 1.451200 1.433550 1.415800 1.397950 1.380000 1.361950 1.343800 1.325550 1.307200 1.288750 1.270200 1.251550 1.232800 1.213950 1.195000 1.175950 1.156800 1.137550 1.118200 1.098750 1.079200 1.059550 1.039800 1.019950 1.000000"
sol_u3 = [float(x) for x in sol_u3.split(" ")]

# %%
def act_u3(x):
    return 2 - x + 0.5*(1 - x**2)

# %%
plt.figure(figsize=(10, 5))
plt.plot(xx, sol_u3[1:], label='finite elem est')
plt.plot(xx, act_u3(xx), label='actual val')
plt.title('f = 1.0, g = 1.0, h = 1.0')
plt.ylabel('u(x)')
plt.xlabel('x')
plt.legend()
plt.savefig('f1_g1_h1.png')
plt.show()
