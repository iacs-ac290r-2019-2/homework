# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
ux = np.genfromtxt('./ux.dat')
ux.shape
# Out:
# (62, 202)

# %%
ux
# Out:
# array([[0.0e+00, 0.0e+00, 0.0e+00, ..., 0.0e+00, 0.0e+00, 0.0e+00],
#        [0.0e+00, 2.1e-05, 3.1e-05, ..., 0.0e+00, 1.0e-05, 0.0e+00],
#        [0.0e+00, 4.5e-05, 6.7e-05, ..., 0.0e+00, 2.3e-05, 0.0e+00],
#        ...,
#        [0.0e+00, 4.6e-05, 6.9e-05, ..., 0.0e+00, 2.3e-05, 0.0e+00],
#        [0.0e+00, 2.1e-05, 3.2e-05, ..., 0.0e+00, 1.1e-05, 0.0e+00],
#        [0.0e+00, 0.0e+00, 0.0e+00, ..., 0.0e+00, 0.0e+00, 0.0e+00]])

# %%
plt.figure(figsize=(20,5))
plt.pcolormesh(ux[1:-1,1:-1])
plt.axis('equal')
plt.colorbar()
plt.show()

# %%
plt.plot(ux[1:-1, 100])  # cross-section, consistent with python version of LBM
